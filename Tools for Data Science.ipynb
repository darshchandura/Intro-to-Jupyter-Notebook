# %%
Title = "Tools for Data Science"

# %%
print("The title of the notebook is",Title)
# Out:
# The title of the notebook is Tools for Data Science

# %%
Introduction = "Data Science is the study of data to find lucrative insights from a large amount of data and use those insights in the decision making process for large MNC's and organizations"

# %%
print("Introduction :",Introduction)
# Out:
# Introduction : Data Science is the study of data to find lucrative insights from a large amount of data and use those insights in the decision making process for large MNC's and organizations

# %%
DSList = ["Python", "Ruby","Java","Matlab","JavaScript"]

# %%
print("Data Science language are:",DSList)
# Out:
# Data Science language are: ['Python', 'Ruby', 'Java', 'Matlab', 'JavaScript']

# %%
DSList2 = ["Pandas", "Scipy","Matplotlib"]

# %%
print("Data Science libraries are:",DSList2)
# Out:
# Data Science libraries are: ['Pandas', 'Scipy', 'Matplotlib']

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabulate import tabulate

# %%
DSTable = [
    ["Python","Pandas"]
]

# %%
Head = ["Languages","Libraries"]

# %%
print(tabulate(DSTable,headers = Head, tablefmt = "grid"))
# Out:
# +-------------+-------------+
# | Languages   | Libraries   |
# +=============+=============+
# | Python      | Pandas      |
# +-------------+-------------+

# %%
Intro2 = "Introducing you all to various arithmetic expressions"

# %%
print("Part 2 :", Intro2)
# Out:
# Part 2 : Introducing you all to various arithmetic expressions

# %%
a = 2
b = 3
c = a+b
d = a*b

# %%
print("Add = ",c, "\nMul = ",d)
# Out:
# Add =  5
# Mul =  6

# %%
Mins = 120
Hours = Mins/60

# %%
print("Total hours = ",Hours)
# Out:
# Total hours =  2.0

# %%
Objectives = "The main objective is to get basic understanding of working with juoyter notebook"

# %%
print("", Objectives)
# Out:
#  The main objective is to get basic understanding of working with juoyter notebook

# %%
AuthorName = "Author Name : Darsh"

# %%
print(AuthorName)
# Out:
# Author Name : Darsh
